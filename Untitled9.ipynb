# %% [markdown]
# <a href="https://colab.research.google.com/github/AntoShine/Amazon/blob/master/Untitled9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as np

# %%
df=np.DataFrame([[1,'Shaji',3],[2,'Lalu',6],[],[4,'Vani',90],[5,'Meera',],[6,'Bilu',78],[7,'Ram',67],[8,'Rose',12],[9,'Teena',45],[10,'Ashua'],[11,'Shobha',28]],columns=['Age','Name','mark'])

# %%
df
# Out:
#      Age    Name  mark
# 0    1.0   Shaji   3.0
# 1    2.0    Lalu   6.0
# 2    NaN    None   NaN
# 3    4.0    Vani  90.0
# 4    5.0   Meera   NaN
# 5    6.0    Bilu  78.0
# 6    7.0     Ram  67.0
# 7    8.0    Rose  12.0
# 8    9.0   Teena  45.0
# 9   10.0   Ashua   NaN
# 10  11.0  Shobha  28.0

# %%
df.isnull()
# Out:
#       Age   Name   mark
# 0   False  False  False
# 1   False  False  False
# 2    True   True   True
# 3   False  False  False
# 4   False  False   True
# 5   False  False  False
# 6   False  False  False
# 7   False  False  False
# 8   False  False  False
# 9   False  False   True
# 10  False  False  False

# %%
df.isnull().sum()
# Out:
# Age     1
# Name    1
# mark    3
# dtype: int64

# %%
df.isnull().sum().sum()
# Out:
# 5

# %%
ad=df.fillna(0)

# %%
ad.isnull()
# Out:
#       Age   Name   mark
# 0   False  False  False
# 1   False  False  False
# 2   False  False  False
# 3   False  False  False
# 4   False  False  False
# 5   False  False  False
# 6   False  False  False
# 7   False  False  False
# 8   False  False  False
# 9   False  False  False
# 10  False  False  False

# %%
ad.isnull().sum().sum()
# Out:
# 0

# %%
af=df.fillna(method='ffill')

# %%
af
# Out:
#      Age    Name  mark
# 0    1.0   Shaji   3.0
# 1    2.0    Lalu   6.0
# 2    2.0    Lalu   6.0
# 3    4.0    Vani  90.0
# 4    5.0   Meera  90.0
# 5    6.0    Bilu  78.0
# 6    7.0     Ram  67.0
# 7    8.0    Rose  12.0
# 8    9.0   Teena  45.0
# 9   10.0   Ashua  45.0
# 10  11.0  Shobha  28.0

# %%
af=df.fillna(method='bfill')

# %%
af
# Out:
#      Age    Name  mark
# 0    1.0   Shaji   3.0
# 1    2.0    Lalu   6.0
# 2    4.0    Vani  90.0
# 3    4.0    Vani  90.0
# 4    5.0   Meera  78.0
# 5    6.0    Bilu  78.0
# 6    7.0     Ram  67.0
# 7    8.0    Rose  12.0
# 8    9.0   Teena  45.0
# 9   10.0   Ashua  28.0
# 10  11.0  Shobha  28.0
